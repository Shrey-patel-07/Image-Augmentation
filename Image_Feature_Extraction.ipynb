# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrey-patel-07/Image-Augmentation/blob/main/Image_Feature_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imshow

image = imread('image_8.png', as_gray=True)
imshow(image)

# %%
image

# %%
image = imread('puppy.jpeg', as_gray=True) 
image.shape, imshow(image)
# Out:
# ((660, 450), <matplotlib.image.AxesImage at 0x7f4e83dae890>)

# %%
image
# Out:
# array([[0.96470588, 0.96470588, 0.96470588, ..., 0.96470588, 0.96470588,
#         0.96470588],
#        [0.96470588, 0.96470588, 0.96470588, ..., 0.96470588, 0.96470588,
#         0.96470588],
#        [0.96470588, 0.96470588, 0.96470588, ..., 0.96470588, 0.96470588,
#         0.96470588],
#        ...,
#        [0.98431373, 0.98431373, 0.98431373, ..., 0.96862745, 0.96470588,
#         0.96470588],
#        [0.98039216, 0.98039216, 0.98039216, ..., 0.96862745, 0.96470588,
#         0.96470588],
#        [0.96862745, 0.96862745, 0.96862745, ..., 0.96862745, 0.96470588,
#         0.96470588]])

# %%
features = np.reshape(image, (660*450))
features.shape, features
# Out:
# ((297000,),
#  array([0.96470588, 0.96470588, 0.96470588, ..., 0.96862745, 0.96470588,
#         0.96470588]))

# %%
image = imread('puppy.jpeg') 
# image.shape
feature_matrix = np.zeros((660,450)) 
feature_matrix.shape
# Out:
# (660, 450)

# %%
for i in range(0,image.shape[0]):
    for j in range(0,image.shape[1]):
        feature_matrix[i][j] = ((int(image[i,j,0]) + int(image[i,j,1]) + int(image[i,j,2]))/3)

# %%
features = np.reshape(feature_matrix, (660*450)) 
features.shape
# Out:
# (297000,)

# %%
from skimage.filters import prewitt_h,prewitt_v
image = imread('puppy.jpeg',as_gray=True)
edges_prewitt_horizontal = prewitt_h(image)
edges_prewitt_vertical = prewitt_v(image)
# imshow(edges_prewitt_vertical, cmap='gray')
imshow(edges_prewitt_horizontal, cmap='gray')

# %%
imshow(edges_prewitt_vertical, cmap='gray')
