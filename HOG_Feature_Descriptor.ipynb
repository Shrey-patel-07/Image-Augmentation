# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrey-patel-07/Image-Augmentation/blob/main/HOG_Feature_Descriptor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt
# %matplotlib inline


#reading the image
img = imread('puppy.jpeg')
imshow(img)
print(img.shape)
# Out:
# (660, 450, 3)

# %%
resized_img = resize(img, (128*4,64*4)) 
imshow(resized_img) 
print(resized_img.shape)
# Out:
# (512, 256, 3)

# %%
fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8), 
                    cells_per_block=(2, 2), visualize=True, channel_axis=-1)
plt.axis("off")
plt.imshow(hog_image, cmap="gray")
plt.show()
